# %%
#Data Wrangling- subsetting and filtering
import pandas as pd
data_load=r'C:\Users\MURERWA DANIEL\Documents\GitHub\DataScience\Data_Dataset\tested.csv'
df=pd.read_csv(data_load)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.columns
df.isna().value_counts()
# Out:
# PassengerId  Survived  Pclass  Name   Sex    Age    SibSp  Parch  Ticket  Fare   Cabin  Embarked
# False        False     False   False  False  False  False  False  False   False  True   False       244
#                                                                                  False  False        87
#                                              True   False  False  False   False  True   False        82
#                                                                                  False  False         4
#                                              False  False  False  False   True   True   False         1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2=df.copy()

# %%
df2.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2.drop(columns='Cabin', axis=1, inplace=True)
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %% [markdown]
# DATA IMPUTATION - RETAINING DATA

# %%
df3=df.copy()
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df3.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df3['Age'].dtype
# Out:
# dtype('float64')

# %%
mean_age=df3.Age.mean()

mean_age
# Out:
# np.float64(30.272590361445783)

# %%
median_age=df3.Age.median()

median_age
# Out:
# 27.0

# %%
modal_age=df3.Age.mode()

modal_age
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
max_age=df3.Age.max()
max_age
min_age=df3.Age.min()
min_age
# Out:
# 0.17

# %%
mode_final=modal_age.mean()
mode_final
# Out:
# np.float64(22.5)

# %%
df3.Age.head(20)
# Out:
# 0     34.5
# 1     47.0
# 2     62.0
# 3     27.0
# 4     22.0
# 5     14.0
# 6     30.0
# 7     26.0
# 8     18.0
# 9     21.0
# 10     NaN
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
# 15    24.0
# 16    35.0
# 17    21.0
# 18    27.0
# 19    45.0
# Name: Age, dtype: float64

# %%
df3['Age'].fillna(value=mean_age).head(20)
# Out:
# 0     34.50000
# 1     47.00000
# 2     62.00000
# 3     27.00000
# 4     22.00000
# 5     14.00000
# 6     30.00000
# 7     26.00000
# 8     18.00000
# 9     21.00000
# 10    30.27259
# 11    46.00000
# 12    23.00000
# 13    63.00000
# 14    47.00000
# 15    24.00000
# 16    35.00000
# 17    21.00000
# 18    27.00000
# 19    45.00000
# Name: Age, dtype: float64

# %%
df3['Age'].fillna(value=median_age).head(20)
# Out:
# 0     34.5
# 1     47.0
# 2     62.0
# 3     27.0
# 4     22.0
# 5     14.0
# 6     30.0
# 7     26.0
# 8     18.0
# 9     21.0
# 10    27.0
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
# 15    24.0
# 16    35.0
# 17    21.0
# 18    27.0
# 19    45.0
# Name: Age, dtype: float64

# %%
df4=df.copy()

# %%
df4['Age'].ffill().head(20)
# Out:
# 0     34.5
# 1     47.0
# 2     62.0
# 3     27.0
# 4     22.0
# 5     14.0
# 6     30.0
# 7     26.0
# 8     18.0
# 9     21.0
# 10    21.0
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
# 15    24.0
# 16    35.0
# 17    21.0
# 18    27.0
# 19    45.0
# Name: Age, dtype: float64

# %% [markdown]
# NEXT OBSERVATION CARRIED BACKWARD

# %%
df4.Age.bfill().head(20)
# Out:
# 0     34.5
# 1     47.0
# 2     62.0
# 3     27.0
# 4     22.0
# 5     14.0
# 6     30.0
# 7     26.0
# 8     18.0
# 9     21.0
# 10    46.0
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
# 15    24.0
# 16    35.0
# 17    21.0
# 18    27.0
# 19    45.0
# Name: Age, dtype: float64

# %% [markdown]
# LINEAR INTERPOLATION

# %%
import numpy as np
a=pd.Series([0,1,np.nan,10])
a
# Out:
# 0     0.0
# 1     1.0
# 2     NaN
# 3    10.0
# dtype: float64

# %%
a.interpolate()
# Out:
# 0     0.0
# 1     1.0
# 2     5.5
# 3    10.0
# dtype: float64

# %%
df4['Age'].head(20)
df4['Age'].interpolate().head(20)
# Out:
# 0     34.5
# 1     47.0
# 2     62.0
# 3     27.0
# 4     22.0
# 5     14.0
# 6     30.0
# 7     26.0
# 8     18.0
# 9     21.0
# 10    33.5
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
# 15    24.0
# 16    35.0
# 17    21.0
# 18    27.0
# 19    45.0
# Name: Age, dtype: float64

# %% [markdown]
# ARBITRARY VALUES

# %%
df4['Age'].head(20)
df['Age'].fillna(0).tail(20)
# Out:
# 398    22.0
# 399    31.0
# 400    30.0
# 401    38.0
# 402    22.0
# 403    17.0
# 404    43.0
# 405    20.0
# 406    23.0
# 407    50.0
# 408     0.0
# 409     3.0
# 410     0.0
# 411    37.0
# 412    28.0
# 413     0.0
# 414    39.0
# 415    38.5
# 416     0.0
# 417     0.0
# Name: Age, dtype: float64

# %% [markdown]
# OUTLIERS

# %%
lists_salaries=[23000, 17000,35000, 28000,39000]
np.mean(lists_salaries)
# Out:
# np.float64(28400.0)

# %%
#Outlier
lists_salaries1=lists_salaries.copy()
lists_salaries1.append(100000)
lists_salaries1
# Out:
# [23000, 17000, 35000, 28000, 39000, 100000]

# %%
df5=df.copy()
df5.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
df5['Age'].head()
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# Name: Age, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df5, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(df5, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df5['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
sns.displot(data=df5, x='Age', bins=10, kde=False)

# %%
sns.scatterplot(data=df5, x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
df5.shape
# Out:
# (418, 12)

# %%
#Quartiles
Q1=df5['Age'].quantile(0.25)
Q3=df5['Age'].quantile(0.75)

IQR=Q3-Q1

# %%
lower_limits=Q1-1.5*IQR
lower_limits
# Out:
# np.float64(-6.0)

# %%
upper_limits=Q3+1.5*IQR
upper_limits
# Out:
# np.float64(66.0)

# %%
outlier_upper= (df5['Age']>upper_limits)
outlier_upper
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
len(df5['Age']-len(df5['Age'][outlier_upper]))
# Out:
# 418

# %%
data_df5=df5[-(outlier_upper)]
data_df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data_df5.shape
# Out:
# (416, 12)

# %%
import pandas as pd
data_url234 = "https://docs.google.com/spreadsheets/d/135Zg2BWZUPC5YAgKyGPwVw2lQf81VlFo8Nk3V1tale0/pubhtml"
dfurl = pd.read_html(data_url234)
dfurl[0].head()  # Display the first table from the HTML
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 data_url234 = "https://docs.google.com/spreadsheets/d/135Zg2BWZUPC5YAgKyGPwVw2lQf81VlFo8Nk3V1tale0/pubhtml"
# ----> 3 dfurl = pd.read_html(data_url234)
#       4 dfurl[0].head()
#
# File c:\Users\MURERWA DANIEL\anaconda3\envs\myenv\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...
