# %% [markdown]
# #### Learning Objectives
#
# ##### *Understand what data wrangling is and why it is important* -> Done
#
# ##### *Perform basic data wrangling tasks like handling missing values*
#
# ##### *Subset datasets using columns & rows*
#
# ##### *Have a sense of how to use Python to wrangle and subset real world data*

# %% [markdown]
# ##### *Technical Definition of Data Wrangling*

# %% [markdown]
# Data wrangling, also known as data munging or data preparation, is the process of cleaning, structuring, and transforming raw data into a usable format for analysis and other data-driven applications. It addresses issues like missing values, inconsistencies, and duplicates to ensure data quality and make it more consumable

# %% [markdown]
# Data wrangling, sometimes referred to as data munging, is the process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics. The goal of data wrangling is to assure quality and useful data. Data analysts typically spend the majority of their time in the process of data wrangling compared to the actual analysis of the data.

# %%
# Cleaning
# Structuring
# Transformation
# Data Quality

# %% [markdown]
# ##### *An Intuitive Explanation of Data Warangling*

# %%
# Raw data == Messy ingredients in your kitchen
# Cook == Analyze
# Before Cooking == Clean, Slice, Organize, etc.
# What is Data Wrangling? == Steps before you are ready to cook

# %% [markdown]
# ##### *Usecase Explanations*

# %%
# Theres a movement from paper registrations to paperless registration - Health
# All paper registrations where transfered to spreadsheets
# A health Analysts (Domain knowledge) need to clean the patients records because there's 
# missing and inconsistent data

# %%
# Clean data for a real estate problem

# %%
# Machine Learning == Inputs + Model + Outputs
# Analyze data to prep for modeling

# %% [markdown]
# #### Set Things UP

# %%
import pandas as pd

# %%
# Sample data
sample_data = {
    'Name': ['Alice', 'Bob', 'Charles', None, 'Eve'],
    'Age': [25, None, -35, 45, 29],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Country': ['Nigeria', 'Kenya', 'Nigeria', 'Ghana', 'Nigeria']
}

# %%
type(sample_data)
# Out:
# dict

# %%
# Create our dataframe
df = pd.DataFrame(sample_data)
df.head()
# Out:
#       Name   Age Gender  Country
# 0    Alice  25.0      F  Nigeria
# 1      Bob   NaN      M    Kenya
# 2  Charles -35.0      M  Nigeria
# 3     None  45.0      M    Ghana
# 4      Eve  29.0      F  Nigeria

# %% [markdown]
# ##### *Data is shared with the immigration Analyst*

# %%
df
# Out:
#       Name   Age Gender  Country
# 0    Alice  25.0      F  Nigeria
# 1      Bob   NaN      M    Kenya
# 2  Charles -35.0      M  Nigeria
# 3     None  45.0      M    Ghana
# 4      Eve  29.0      F  Nigeria

# %%
# Concise summary of the data
# ?df.info
# Out:
# Signature:
# df.info(
#     verbose: 'bool | None' = None,
#     buf: 'WriteBuffer[str] | None' = None,
#     max_cols: 'int | None' = None,
#     memory_usage: 'bool | str | None' = None,
#     show_counts: 'bool | None' = None,
# ) -> 'None'
# Docstring:
# Print a concise summary of a DataFrame.
#
# This method prints information about a DataFrame including
# the index dtype and columns, non-null values and memory usage.
#
# Parameters
# ----------
# verbose : bool, optional
#     Whether to print the full summary. By default, the setting in
#     ``pandas.options.display.max_info_columns`` is followed.
# buf : writable buffer, defaults to sys.stdout
#     Where to send the output. By default, the output is printed to
#     sys.stdout. Pass a writable buffer if you need to further process
#     the output.
# max_cols : int, optional
#     When to switch from the verbose to the truncated output. If the
#     DataFrame has more than `max_cols` columns, the truncated output
#     is used. By default, the setting in
#     ``pandas.options.display.max_info_columns`` is used.
# memory_usage : bool, str, optional
#     Specifies whether total memory usage of the DataFrame
#     elements (including the index) should be displayed. By default,
#     this follows the ``pandas.options.display.memory_usage`` setting.
#
#     True always show memory usage. False never shows memory usage.
#     A value of 'deep' is equivalent to "True with deep introspection".
#     Memory usage is shown in human-readable units (base-2
#     representation). Without deep introspection a memory estimation is
#     made based in column dtype and number of rows assuming values
#     consume the same memory amount for corresponding dtypes. With deep
#     memory introspection, a real memory usage calculation is performed
#     at the cost of computational resources. See the
#     :ref:`Frequently Asked Questions <df-memory-usage>` for more
#     details.
# show_counts : bool, optional
#     Whether to show the non-null counts. By default, this is shown
#     only if the DataFrame is smaller than
#     ``pandas.options.display.max_info_rows`` and
#     ``pandas.options.display.max_info_columns``. A value of True always
#     shows the counts, and False never shows the counts.
#
# Returns
# -------
# None
#     This method prints a summary of a DataFrame and returns None.
#
# See Also
# --------
# DataFrame.describe: Generate descriptive statistics of DataFrame
#     columns.
# DataFrame.memory_usage: Memory usage of DataFrame columns.
#
# Examples
# --------
# >>> int_values = [1, 2, 3, 4, 5]
# >>> text_values = ['alpha', 'beta', 'gamma', 'delta', 'epsilon']
# >>> float_values = [0.0, 0.25, 0.5, 0.75, 1.0]
# >>> df = pd.DataFrame({"int_col": int_values, "text_col": text_values,
# ...                   "float_col": float_values})
# >>> df
#     int_col text_col  float_col
# 0        1    alpha       0.00
# 1        2     beta       0.25
# 2        3    gamma       0.50
# 3        4    delta       0.75
# 4        5  epsilon       1.00
#
# Prints information of all columns:
#
# >>> df.info(verbose=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   int_col    5 non-null      int64
#  1   text_col   5 non-null      object
#  2   float_col  5 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes
#
# Prints a summary of columns count and its dtypes but not per column
# information:
#
# >>> df.info(verbose=False)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Columns: 3 entries, int_col to float_col
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes
#
# Pipe output of DataFrame.info to buffer instead of sys.stdout, get
# buffer content and writes to a text file:
#
# >>> import io
# >>> buffer = io.StringIO()
# >>> df.info(buf=buffer)
# >>> s = buffer.getvalue()
# >>> with open("df_info.txt", "w",
# ...           encoding="utf-8") as f:  # doctest: +SKIP
# ...     f.write(s)
# 260
#
# The `memory_usage` parameter allows deep introspection mode, specially
# useful for big DataFrames and fine-tune memory optimization:
#
# >>> random_strings_array = np.random.choice(['a', 'b', 'c'], 10 ** 6)
# >>> df = pd.DataFrame({
# ...     'column_1': np.random.choice(['a', 'b', 'c'], 10 ** 6),
# ...     'column_2': np.random.choice(['a', 'b', 'c'], 10 ** 6),
# ...     'column_3': np.random.choice(['a', 'b', 'c'], 10 ** 6)
# ... })
# >>> df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   column_1  1000000 non-null  object
#  1   column_2  1000000 non-null  object
#  2   column_3  1000000 non-null  object
# dtypes: object(3)
# memory usage: 22.9+ MB
#
# >>> df.info(memory_usage='deep')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   column_1  1000000 non-null  object
#  1   column_2  1000000 non-null  object
#  2   column_3  1000000 non-null  object
# dtypes: object(3)
# memory usage: 165.9 MB
# File:      /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py
# Type:      method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     4 non-null      object
#  1   Age      4 non-null      float64
#  2   Gender   5 non-null      object
#  3   Country  5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 292.0+ bytes

# %% [markdown]
# ##### *Handle the missing values*

# %%
df['Name'] = df['Name'].fillna('Grid Loss')

# %%
df
# Out:
#         Name   Age Gender  Country
# 0      Alice  25.0      F  Nigeria
# 1        Bob   NaN      M    Kenya
# 2    Charles -35.0      M  Nigeria
# 3  Grid Loss  45.0      M    Ghana
# 4        Eve  29.0      F  Nigeria

# %%
# Indexer (loc/iloc)

# %%
df.iloc[2, 1] = 'Grid Loss' # Position based indexing
# Out:
# /var/folders/dy/cw3jgpfj77gbfn_1svh5cj4c0000gn/T/ipykernel_96196/622556726.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Grid Loss' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.iloc[2, 1] = 'Grid Loss' # Position based indexing

# %%
df
# Out:
#         Name        Age Gender  Country
# 0      Alice       25.0      F  Nigeria
# 1        Bob        NaN      M    Kenya
# 2    Charles  Grid Loss      M  Nigeria
# 3  Grid Loss       45.0      M    Ghana
# 4        Eve       29.0      F  Nigeria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Age      4 non-null      object
#  2   Gender   5 non-null      object
#  3   Country  5 non-null      object
# dtypes: object(4)
# memory usage: 292.0+ bytes

# %% [markdown]
# ##### *Changing data types*

# %%
#df['Age'] = df['Age'].astype(float)

# %%
# To solve
import numpy as np
pd.set_option('future.no_silent_downcasting', True)

# %%
df['Age'] = df['Age'].replace(['Grid Loss'], np.nan)

# %%
df
# Out:
#         Name   Age Gender  Country
# 0      Alice  25.0      F  Nigeria
# 1        Bob   NaN      M    Kenya
# 2    Charles   NaN      M  Nigeria
# 3  Grid Loss  45.0      M    Ghana
# 4        Eve  29.0      F  Nigeria

# %% [markdown]
# ##### *Focus on what we need*

# %%
# Sselect specific columns
df_demo = df[['Name', 'Age', 'Country']]

# %%
df_demo
# Out:
#         Name   Age  Country
# 0      Alice  25.0  Nigeria
# 1        Bob   NaN    Kenya
# 2    Charles   NaN  Nigeria
# 3  Grid Loss  45.0    Ghana
# 4        Eve  29.0  Nigeria

# %%
# Select based on rows
df_ngr = df[df['Country'] == 'Nigeria']

# %%
df['Country'] == 'Nigeria' # Boolean Output
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Country, dtype: bool

# %%
df_ngr
# Out:
#       Name   Age Gender  Country
# 0    Alice  25.0      F  Nigeria
# 2  Charles   NaN      M  Nigeria
# 4      Eve  29.0      F  Nigeria

# %% [markdown]
# #### Consider this real data

# %%
house_data = pd.read_csv('house_data.csv')
house_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Subsetted based on columns

# %%
house_data_sub = house_data[['Id','MSSubClass','MSZoning','LotFrontage','LotArea']]

# %%
house_data_sub.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea
# 0   1          60       RL         65.0     8450
# 1   2          20       RL         80.0     9600
# 2   3          60       RL         68.0    11250
# 3   4          70       RL         60.0     9550
# 4   5          60       RL         84.0    14260

# %%
# Subset based on rows
house_data_sub20 = house_data_sub[house_data_sub['MSSubClass']== 20]

# %%
house_data_sub20.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea
# 1    2          20       RL         80.0     9600
# 6    7          20       RL         75.0    10084
# 10  11          20       RL         70.0    11200
# 12  13          20       RL          NaN    12968
# 13  14          20       RL         91.0    10652

# %% [markdown]
# #### Data Wrangling & Filtering

# %% [markdown]
# #### Learning Objectives
#
# ##### *Understand Data Wrangling & Filtering (Contextually)* - Done
#
# ##### *Use the Pandas Module to Filter Data* - Done
#
# ##### *Understand the business case for filtering Data* - Done

# %% [markdown]
# ##### *Filtering*

# %%
# It is a process of subsetting rows based on Boolean conditions
# It allows us to focus on relevant data for data analysis and visualization

# %% [markdown]
# ##### *Use cases*

# %%
# HR & Recruitment Analytics: 
# Filter employees or Job seekers based on some conditions
# Business Value: Employee Management & Talent Recruitment

# %%
# Marketing Analytics: 
# Filtering for target customers based on buying psychology/Demographics 
# Business Value: Profit/Sales/High Conversion targets

# %%
# Retail Analytics: 
# Inventory of Product Status
# Business Value: Reodering logic/model for just-in-time inventory

# %%
# Financial Analytic: 
# Audit Transactions for certain Thresholds 
# Business Value: Fraud Detection & Financial Compliance

# %%
# Health Analytics:
# Tracking Patient Visits
# Business Value: Build model for reminders

# %%
import pandas as pd # Data Manipulation Library

# %%
# Create Mock Data
student_data = {
        'student name': ['Precious Ayoola', 'Praise Sanni', 'Yao Theodore', 'Olivier Dusabamahoro', 'Daniel Murerwa'],
        'City': ['Lagos', 'Kaduna', 'Lome', 'Kigali', 'Nairobi'],
        'Age': [23, 21, 25, 20, 22],
        'Score': [88, 92, 76, 65, 99]
}

# %%
df = pd.DataFrame(student_data)
df
# Out:
#            student name     City  Age  Score
# 0       Precious Ayoola    Lagos   23     88
# 1          Praise Sanni   Kaduna   21     92
# 2          Yao Theodore     Lome   25     76
# 3  Olivier Dusabamahoro   Kigali   20     65
# 4        Daniel Murerwa  Nairobi   22     99

# %%
# Filter rows for scores
df['Score'] >= 90
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Score, dtype: bool

# %%
df[df['Score'] >= 90]
# Out:
#      student name     City  Age  Score
# 1    Praise Sanni   Kaduna   21     92
# 4  Daniel Murerwa  Nairobi   22     99

# %%
df_90 = df[df['Score'] >= 90]

# %%
# Filter for City
df['City'] == 'Kigali'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: City, dtype: bool

# %%
df[df['City'] == 'Kigali']
# Out:
#            student name    City  Age  Score
# 3  Olivier Dusabamahoro  Kigali   20     65

# %%
# Filter for city and score
# City - Lagos & Score > 70

# %%
df['City'] == 'Lagos'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: City, dtype: bool

# %%
df['Score'] > 70
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Score, dtype: bool

# %%
(df['City'] == 'Lagos') & (df['Score'] > 70)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[(df['City'] == 'Lagos') & (df['Score'] > 70)]
# Out:
#       student name   City  Age  Score
# 0  Precious Ayoola  Lagos   23     88

# %%
#(df['City'] == 'Lagos') and (df['Score'] > 70)

# %%
# Filter for people from Lagos or Nairobi
['Lagos', 'Nairobi']
# Out:
# ['Lagos', 'Nairobi']

# %%
df['City']
# Out:
# 0      Lagos
# 1     Kaduna
# 2       Lome
# 3     Kigali
# 4    Nairobi
# Name: City, dtype: object

# %%
# .isin

# %%
df['City'].isin(['Lagos', 'Nairobi'])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: City, dtype: bool

# %%
df[df['City'].isin(['Lagos', 'Nairobi'])]
# Out:
#       student name     City  Age  Score
# 0  Precious Ayoola    Lagos   23     88
# 4   Daniel Murerwa  Nairobi   22     99

# %%
# Filter for rows where names contain the letter a
# a is case-sensitive

# %%
df['student name']
# Out:
# 0         Precious Ayoola
# 1            Praise Sanni
# 2            Yao Theodore
# 3    Olivier Dusabamahoro
# 4          Daniel Murerwa
# Name: student name, dtype: object

# %%
# contains 'a'
df['student name'].str.contains('d', case=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: student name, dtype: bool

# %%
df[df['student name'].str.contains('d', case=False)]
# Out:
#            student name     City  Age  Score
# 2          Yao Theodore     Lome   25     76
# 3  Olivier Dusabamahoro   Kigali   20     65
# 4        Daniel Murerwa  Nairobi   22     99

# %% [markdown]
# ##### *Why is filtering Important?*

# %%
# Large data easier to digest
# Focuses on relevant insights
# Improve decision-making speed

# %% [markdown]
# ##### *Retail Analtics (Fashion)*

# %%
# !head dataset_fashion_store_products.csv
# Out:
# product_id,product_name,category,brand,color,size,catalog_price,cost_price,gender
# 1,Soft Wrap Dress,Dresses,Tiva,Green,S,40.41,20.7,Female
# 2,Soft Wrap Tee,T-Shirts,Tiva,White,S,78.45,53.76,Female
# 3,Soft Linen Tee,T-Shirts,Tiva,Green,XL,23.9,14.81,Female
# 4,Soft Ribbed Tee,T-Shirts,Tiva,White,S,60,34.78,Female
# 5,Soft Wrap Trousers,Pants,Tiva,Blue,M,36.84,16.46,Female
# 6,Soft Wrap Shoes,Shoes,Tiva,Green,36,70.86,31.66,Female
# 7,Soft Linen Dress,Dresses,Tiva,White,M,57.66,24.07,Female
# 8,Soft Linen Trousers,Pants,Tiva,Green,M,50.91,33.59,Female
# 9,Soft Linen Shoes,Shoes,Tiva,Red,40,40.5,23.5,Female

# %%
fashionStore_data = pd.read_csv('dataset_fashion_store_products.csv')
fashionStore_data.head()
# Out:
#    product_id        product_name  category brand  color size  catalog_price  \
# 0           1     Soft Wrap Dress   Dresses  Tiva  Green    S          40.41
# 1           2       Soft Wrap Tee  T-Shirts  Tiva  White    S          78.45
# 2           3      Soft Linen Tee  T-Shirts  Tiva  Green   XL          23.90
# 3           4     Soft Ribbed Tee  T-Shirts  Tiva  White    S          60.00
# 4           5  Soft Wrap Trousers     Pants  Tiva   Blue    M          36.84
#
#    cost_price  gender
# 0       20.70  Female
# 1       53.76  Female
# 2       14.81  Female
# 3       34.78  Female
# 4       16.46  Female

# %%
# Filter for Size
fashionStore_data['size'] == 'S'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 495     True
# 496    False
# 497    False
# 498    False
# 499    False
# Name: size, Length: 500, dtype: bool

# %%
fashionStore_data[fashionStore_data['size'] == 'S'].head()
# Out:
#     product_id     product_name  category brand  color size  catalog_price  \
# 0            1  Soft Wrap Dress   Dresses  Tiva  Green    S          40.41
# 1            2    Soft Wrap Tee  T-Shirts  Tiva  White    S          78.45
# 3            4  Soft Ribbed Tee  T-Shirts  Tiva  White    S          60.00
# 14          15  Soft Cotton Tee  T-Shirts  Tiva   Blue    S          61.26
# 18          19  Soft Silk Dress   Dresses  Tiva   Blue    S          65.26
#
#     cost_price  gender
# 0        20.70  Female
# 1        53.76  Female
# 3        34.78  Female
# 14       27.85  Female
# 18       34.56  Female

# %%
fashionStore_data_small = fashionStore_data[fashionStore_data['size'] == 'S']

# %%
fashionStore_data_small.head(20)
# Out:
#      product_id             product_name   category brand  color size  \
# 0             1          Soft Wrap Dress    Dresses  Tiva  Green    S
# 1             2            Soft Wrap Tee   T-Shirts  Tiva  White    S
# 3             4          Soft Ribbed Tee   T-Shirts  Tiva  White    S
# 14           15          Soft Cotton Tee   T-Shirts  Tiva   Blue    S
# 18           19          Soft Silk Dress    Dresses  Tiva   Blue    S
# 23           24    Soft High-Waist Dress    Dresses  Tiva  Green    S
# 33           34       Modern Linen Dress    Dresses  Tiva  Green    S
# 44           45      Soft Sleeveless Tee   T-Shirts  Tiva    Red    S
# 58           59            Soft Silk Set  Sleepwear  Tiva   Blue    S
# 65           66  Modern High-Waist Dress    Dresses  Tiva  Black    S
# 79           80     Classic Ribbed Dress    Dresses  Tiva  Black    S
# 81           82     Classic Cotton Dress    Dresses  Tiva  Green    S
# 101         102        Classic Linen Tee   T-Shirts  Tiva  Green    S
# 102         103       Classic Ribbed Tee   T-Shirts  Tiva   Blue    S
# 104         105       Classic Cotton Tee   T-Shirts  Tiva  Black    S
# 107         108     Modern Crew Trousers      Pants  Tiva  Green    S
# 119         120          Modern Boxy Set  Sleepwear  Tiva  Green    S
# 122         123         Classic Wrap Set  Sleepwear  Tiva  White    S
# 123         124        Classic Linen Set  Sleepwear  Tiva  White    S
# 130         131       Classic Cotton Set  Sleepwear  Tiva  Black    S
#
#      catalog_price  cost_price  gender
# 0            40.41       20.70  Female
# 1            78.45       53.76  Female
# 3            60.00       34.78  Female
# 14           61.26       27.85  Female
# 18           65.26       34.56  Female
# 23           42.76       21.80  Female
# 33           48.34       33.10  Female
# 44           54.16       25.87  Female
# 58           34.58       14.30  Female
# 65           24.13       13.58  Female
# 79           31.86       13.85  Female
# 81           32.21       18.91  Female
# 101          43.06       25.45  Female
# 102          57.00       28.18  Female
# 104          36.90       24.81  Female
# 107          48.19       30.20  Female
# 119          25.70       14.44  Female
# 122          61.51       30.47  Female
# 123          55.04       23.83  Female
# 130          66.63       35.00  Female

# %%
fashionStore_data_small['color'].value_counts()
# Out:
# color
# White    20
# Black    20
# Green    17
# Blue     14
# Red      13
# Name: count, dtype: int64

# %%
fashionStore_data_small['category'].value_counts()
# Out:
# category
# T-Shirts     29
# Dresses      23
# Sleepwear    23
# Pants         9
# Name: count, dtype: int64

# %%
# Filter for colors blue, green & red
['Green', 'Blue', 'Red']
# Out:
# ['Green', 'Blue', 'Red']

# %%
color_pref_kids = fashionStore_data_small[fashionStore_data_small['color'].isin(['Green', 'Blue', 'Red'])]

# %%
color_pref_kids.head()
# Out:
#     product_id           product_name  category brand  color size  \
# 0            1        Soft Wrap Dress   Dresses  Tiva  Green    S
# 14          15        Soft Cotton Tee  T-Shirts  Tiva   Blue    S
# 18          19        Soft Silk Dress   Dresses  Tiva   Blue    S
# 23          24  Soft High-Waist Dress   Dresses  Tiva  Green    S
# 33          34     Modern Linen Dress   Dresses  Tiva  Green    S
#
#     catalog_price  cost_price  gender
# 0           40.41       20.70  Female
# 14          61.26       27.85  Female
# 18          65.26       34.56  Female
# 23          42.76       21.80  Female
# 33          48.34       33.10  Female

# %%
color_pref_kids['gender'].value_counts()
# Out:
# gender
# Female    44
# Name: count, dtype: int64

# %% [markdown]
# #### Assignment
#
# ##### Using the fashion store dataset, employ subsetting and filtering to extract
#
# ##### the product name, color and brand name of products with cost price between
#
# ##### 10.00 to 30.00
#
#
# ###### *Submission instructions: Submit the Jupyter notebook inside the message thread*
# ###### *where I share the 2nd live class notebook in our community platform*
#
# ###### *Submission Deadline: July 17, 11:59pm*
#
# ###### *Deadlines are firm*
#
# ###### *Dataset: https://drive.google.com/file/d/12553vFFFSyFv9TYDQXK6zSYg_DVZXyJh/view?usp=sharing*

# %% [markdown]
# #### Data Aggregation

# %% [markdown]
# #### Learning Objectives
#
# ##### *Understand the intuition behind data aggregation* Done
#
# ##### *Understand how to aggregate data using the Pandas groupby function* Done
#
# ##### *Understand how to aggregate using a dataset* Done

# %% [markdown]
# ##### *Technical Definition*

# %% [markdown]
# Data aggregation is a process of applying summary statistics to grouped subsets of data.
#
# This is done using the Pandas groupby method

# %% [markdown]
# ##### *Non-Technical Definition*

# %% [markdown]
# Grouping similar things together and summarizing them so its easire to understand

# %% [markdown]
# ##### *Why is data aggregation important in real-world problem solving?*

# %%
# Retail usecase -> Summarize product/store sales
# Public Policy usecase -> Group data for income analysis, gender for equity analysis 
# Group by demographies to understand poverty distributions 
# Group by locations to understand food insecurities 
# Group by location to understand disease breakout
# Logistic Usecase - Group by cities to understand delivery challenges

# %% [markdown]
# ##### *A simple example of a groupby function*

# %%
# Create a simple dataframe
import pandas as pd

# %%
data = {
    'Store Location': ['Lagos', 'Lagos', 'Abuja', 'Abuja', 'Kano'],
    'Product': ['Bread', 'Milk', 'Bread', 'Milk', 'Bread'],
    'Sales': [100, 200, 150, 250, 50]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Store Location Product  Sales
# 0          Lagos   Bread    100
# 1          Lagos    Milk    200
# 2          Abuja   Bread    150
# 3          Abuja    Milk    250
# 4           Kano   Bread     50

# %% [markdown]
# ##### *For a store location, what is their total sales?*

# %%
# ?df.groupby
# Out:
# Signature:
# df.groupby(
#     by=None,
#     axis: 'Axis | lib.NoDefault' = <no_default>,
#     level: 'IndexLabel | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     dropna: 'bool' = True,
# ) -> 'DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, pd.Grouper or list of such
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
#     aligned; see ``.align()`` method). If a list or ndarray of length
#     equal to the selected axis is passed (see the `groupby user guide
#     <https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html#splitting-an-object-into-groups>`_),
#     the values are used as-is to determine the groups. A label or list
#     of labels may be passed to group by the columns in ``self``.
#     Notice that a tuple is interpreted as a (single) key.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Split along rows (0) or columns (1). For `Series` this parameter
#     is unused and defaults to 0.
#
#     .. deprecated:: 2.1.0
#
#         Will be removed and behave like axis=0 in a future version.
#         For ``axis=1``, do ``frame.T.groupby(...)`` instead.
#
# level : int, level name, or sequence of such, default None
#     If the axis is a MultiIndex (hierarchical), group by a particular
#     level or levels. Do not specify both ``by`` and ``level``.
# as_index : bool, default True
#     Return object with group labels as the
#     index. Only relevant for DataFrame input. as_index=False is
#     effectively "SQL-style" grouped output. This argument has no effect
#     on filtrations (see the `filtrations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#filtration>`_),
#     such as ``head()``, ``tail()``, ``nth()`` and in transformations
#     (see the `transformations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#transformation>`_).
# sort : bool, default True
#     Sort group keys. Get better performance by turning this off.
#     Note this does not influence the order of observations within each
#     group. Groupby preserves the order of rows within each group. If False,
#     the groups will appear in the same order as they did in the original DataFrame.
#     This argument has no effect on filtrations (see the `filtrations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#filtration>`_),
#     such as ``head()``, ``tail()``, ``nth()`` and in transformations
#     (see the `transformations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#transformation>`_).
#
#     .. versionchanged:: 2.0.0
#
#         Specifying ``sort=False`` with an ordered categorical grouper will no
#         longer sort the values.
#
# group_keys : bool, default True
#     When calling apply and the ``by`` argument produces a like-indexed
#     (i.e. :ref:`a transform <groupby.transform>`) result, add group keys to
#     index to identify pieces. By default group keys are not included
#     when the result's index (and column) labels match the inputs, and
#     are included otherwise.
#
#     .. versionchanged:: 1.5.0
#
#        Warns that ``group_keys`` will no longer be ignored when the
#        result from ``apply`` is a like-indexed Series or DataFrame.
#        Specify ``group_keys`` explicitly to include the group keys or
#        not.
#
#     .. versionchanged:: 2.0.0
#
#        ``group_keys`` now defaults to ``True``.
#
# observed : bool, default False
#     This only applies if any of the groupers are Categoricals.
#     If True: only show observed values for categorical groupers.
#     If False: show all values for categorical groupers.
#
#     .. deprecated:: 2.1.0
#
#         The default value will change to True in a future version of pandas.
#
# dropna : bool, default True
#     If True, and if group keys contain NA values, NA values together
#     with row/column will be dropped.
#     If False, NA values will also be treated as the key in groups.
#
# Returns
# -------
# pandas.api.typing.DataFrameGroupBy
#     Returns a groupby object that contains information about the groups.
#
# See Also
# --------
# resample : Convenience method for frequency conversion and resampling
#     of time series.
#
# Notes
# -----
# See the `user guide
# <https://pandas.pydata.org/pandas-docs/stable/groupby.html>`__ for more
# detailed usage and examples, including splitting an object into groups,
# iterating through groups, selecting a group, aggregation, and more.
#
# Examples
# --------
# >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
# ...                               'Parrot', 'Parrot'],
# ...                    'Max Speed': [380., 370., 24., 26.]})
# >>> df
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0
# >>> df.groupby(['Animal']).mean()
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0
#
# **Hierarchical Indexes**
#
# We can groupby different levels of a hierarchical index
# using the `level` parameter:
#
# >>> arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
# ...           ['Captive', 'Wild', 'Captive', 'Wild']]
# >>> index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
# >>> df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
# ...                   index=index)
# >>> df
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0
# >>> df.groupby(level=0).mean()
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0
# >>> df.groupby(level="Type").mean()
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0
#
# We can also choose to include NA in group keys or not by setting
# `dropna` parameter, the default setting is `True`.
#
# >>> l = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
# >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# >>> df.groupby(by=["b"]).sum()
#     a   c
# b
# 1.0 2   3
# 2.0 2   5
#
# >>> df.groupby(by=["b"], dropna=False).sum()
#     a   c
# b
# 1.0 2   3
# 2.0 2   5
# NaN 1   4
#
# >>> l = [["a", 12, 12], [None, 12.3, 33.], ["b", 12.3, 123], ["a", 1, 1]]
# >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# >>> df.groupby(by="a").sum()
#     b     c
# a
# a   13.0   13.0
# b   12.3  123.0
#
# >>> df.groupby(by="a", dropna=False).sum()
#     b     c
# a
# a   13.0   13.0
# b   12.3  123.0
# NaN 12.3   33.0
#
# When using ``.apply()``, use ``group_keys`` to include or exclude the
# group keys. The ``group_keys`` argument defaults to ``True`` (include).
#
# >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
# ...                               'Parrot', 'Parrot'],
# ...                    'Max Speed': [380., 370., 24., 26.]})
# >>> df.groupby("Animal", group_keys=True)[['Max Speed']].apply(lambda x: x)
#           Max Speed
# Animal
# Falcon 0      380.0
#        1      370.0
# Parrot 2       24.0
#        3       26.0
#
# >>> df.groupby("Animal", group_keys=False)[['Max Speed']].apply(lambda x: x)
#    Max Speed
# 0      380.0
# 1      370.0
# 2       24.0
# 3       26.0
# File:      /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py
# Type:      method

# %%
df.groupby('Store Location')['Sales']

# %%
df.groupby('Store Location')['Sales'].sum()
# Out:
# Store Location
# Abuja    400
# Kano      50
# Lagos    300
# Name: Sales, dtype: int64

# %% [markdown]
# ##### *Other Aggregation Functions*

# %% [markdown]
# .sum()
#
# .mean()
#
# .median()
#
# .count()
#
# .max()/min()
#
# .agg()

# %%
df.groupby('Store Location')['Sales'].agg(['sum', 'mean', 'count'])
# Out:
#                 sum   mean  count
# Store Location
# Abuja           400  200.0      2
# Kano             50   50.0      1
# Lagos           300  150.0      2

# %% [markdown]
# ##### *Why do we summarize data?*

# %% [markdown]
# 1. Quick Insights
#
# 2. Raw data to informed decisions
#
# 3. Unsual Trends
#
# 4. Data Reduction for clarity
#
# 5. Data Visualization

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# #### Use groupby on a dataset

# %%
housing_data = pd.read_csv('house_data.csv')
house_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# ##### *Are house prices increasing or decreasing by year?*

# %%
# Year Sold
# House Price

# %%
house_data.groupby('YrSold')['SalePrice'].mean()
# Out:
# YrSold
# 2006    182549.458599
# 2007    186063.151976
# 2008    177360.838816
# 2009    179432.103550
# 2010    177393.674286
# Name: SalePrice, dtype: float64

# %%
house_data.groupby('YrSold')['SalePrice'].median()
# Out:
# YrSold
# 2006    163995.0
# 2007    167000.0
# 2008    164000.0
# 2009    162000.0
# 2010    155000.0
# Name: SalePrice, dtype: float64

# %% [markdown]
# ##### *Do land size increase based on housing zones?*

# %%
house_data['MSZoning'].head()
# Out:
# 0    RL
# 1    RL
# 2    RL
# 3    RL
# 4    RL
# Name: MSZoning, dtype: object

# %%
# Feature Transformation 
house_data['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
zoning_housing = {"RL": "Residential Low Density",
"RM": "Residential Medium Density",
"C (all)": "Commercial",
"FV": "Floating Village Residential",
"RH": "Floating Village Residential"}

# %%
house_data['Zone Identifier'] = house_data['MSZoning'].replace(zoning_housing)

# %%
house_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice          Zone Identifier
# 0       WD        Normal     208500  Residential Low Density
# 1       WD        Normal     181500  Residential Low Density
# 2       WD        Normal     223500  Residential Low Density
# 3       WD       Abnorml     140000  Residential Low Density
# 4       WD        Normal     250000  Residential Low Density

# %%
house_data['Zone Identifier'].value_counts(normalize=True)
# Out:
# Zone Identifier
# Residential Low Density         0.788356
# Residential Medium Density      0.149315
# Floating Village Residential    0.055479
# Commercial                      0.006849
# Name: proportion, dtype: float64

# %%
house_data['LotArea'].head()
# Out:
# 0     8450
# 1     9600
# 2    11250
# 3     9550
# 4    14260
# Name: LotArea, dtype: int64

# %%
# Groupby function
house_data.groupby('Zone Identifier')['LotArea'].median()
# Out:
# Zone Identifier
# Commercial                       8606.0
# Floating Village Residential     7500.0
# Residential Low Density         10004.0
# Residential Medium Density       6000.0
# Name: LotArea, dtype: float64

# %%
house_data.groupby('Zone Identifier')['LotArea'].agg(['median', 'mean', 'sum'])
# Out:
#                                median          mean       sum
# Zone Identifier
# Commercial                     8606.0   9501.300000     95013
# Floating Village Residential   7500.0   6785.271605    549607
# Residential Low Density       10004.0  11571.814075  13319158
# Residential Medium Density     6000.0   6379.775229   1390791

# %% [markdown]
# ##### *Sales based on zones*

# %%
house_data.groupby('Zone Identifier')['SalePrice'].agg(['mean', 'median', 'count'])
# Out:
#                                        mean    median  count
# Zone Identifier
# Commercial                     74528.000000   74700.0     10
# Floating Village Residential  197726.518519  185000.0     81
# Residential Low Density       191004.994787  174000.0   1151
# Residential Medium Density    126316.830275  120500.0    218

# %% [markdown]
# ##### *Can we group by more than one feature?*

# %% [markdown]
# ##### *Average sale price based on year sold & zone*

# %%
house_data.groupby(['YrSold', 'Zone Identifier'])['SalePrice'].median()
# Out:
# YrSold  Zone Identifier
# 2006    Commercial                       71655.5
#         Floating Village Residential    179950.0
#         Residential Low Density         174900.0
#         Residential Medium Density      121950.0
# 2007    Commercial                      133900.0
#         Floating Village Residential    177000.0
#         Residential Low Density         176742.5
#         Residential Medium Density      122000.0
# 2008    Commercial                       60500.0
#         Floating Village Residential    196000.0
#         Residential Low Density         173500.0
#         Residential Medium Density      128000.0
# 2009    Commercial                       59950.0
#         Floating Village Residential    208300.0
#         Residential Low Density         173750.0
#         Residential Medium Density      115000.0
# 2010    Commercial                       68400.0
#         Floating Village Residential    215600.0
#         Residential Low Density         166000.0
#         Residential Medium Density      115000.0
# Name: SalePrice, dtype: float64
