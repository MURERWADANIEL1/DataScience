# %% [markdown]
# Learning Data Wrangling
# Basic Data Wrangling
# Subset datasets using columns and rows
# How to use Python to wrangle and subset real world data

# %% [markdown]
# Data Cleaning
# Structuring
# Trnasformation
# Data Quality

# %% [markdown]
# Raw Data ==Messy ingridients in your kitchn
# cook==analyze
# before cooking==clean,slice,organize, etc
#
# wrangling==steps before you are ready to cook

# %% [markdown]
# UseCase Explanations
#
# cleaning patient records

# %%
#Settind things up
import pandas as pd
sample_data={
    'Name':['Alice', 'Bob', 'Charlie', 'David', 'Eve',''],
    'Age':[25, 30, 35, -25, 0, 45],
    'Gende':['female', 'male', 'male', 'male','female', 'null'],
    'Country':['USA', 'Canada', 'UK', 'Uganda', 'Canada', 'Uganda'],

}
df=pd.DataFrame(sample_data)
type(df)
df.head(10)
# Out:
#       Name  Age   Gende Country
# 0    Alice   25  female     USA
# 1      Bob   30    male  Canada
# 2  Charlie   35    male      UK
# 3    David  -25    male  Uganda
# 4      Eve    0  female  Canada
# 5            45    null  Uganda

# %%
#Handling Missing Values
df['Name']=df['Name'].fillna('Grid Loss')
df.head(10)
# Out:
#       Name  Age   Gende Country
# 0    Alice   25  female     USA
# 1      Bob   30    male  Canada
# 2  Charlie   35    male      UK
# 3    David  -25    male  Uganda
# 4      Eve    0  female  Canada
# 5            45    null  Uganda

# %%
df.iloc[5,0]='Grid Loss'
df.head(10)
# Out:
#         Name  Age   Gende Country
# 0      Alice   25  female     USA
# 1        Bob   30    male  Canada
# 2    Charlie   35    male      UK
# 3      David  -25    male  Uganda
# 4        Eve    0  female  Canada
# 5  Grid Loss   45    null  Uganda

# %%
df_demo=df[['Name', 'Age', 'Country']]
df_demo
# Out:
#         Name  Age Country
# 0      Alice   25     USA
# 1        Bob   30  Canada
# 2    Charlie   35      UK
# 3      David  -25  Uganda
# 4        Eve    0  Canada
# 5  Grid Loss   45  Uganda

# %%
df['Country']=='Uganda'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: Country, dtype: bool

# %%
df_ug=df['Country']=='Uganda'
df_ug
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: Country, dtype: bool

# %%
datas=r'C:\Users\MURERWA DANIEL\Documents\GitHub\DataScience\Data_Dataset\housing.csv'
df1=pd.read_csv(datas)
df1.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...
